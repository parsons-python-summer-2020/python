# %% [markdown]
# # Palindrome - live code
#
#
# ## What is a palindrome?
# A palindrome is a word or phrase that is spelled the same forwards as backwards, like:
#
# ```
# wow
# Anna
# race car
# Was it a cat I saw?
# ```
#
# ## What will we make?
# We are going to create a function that checks whether or not a given phrase is a palindrome. Here's the plan:
# * Our function will be called `isPalindrome()`.
# * It will accept one **argument** called `txt`, which is a string.
# * It will print True if `txt` is a palindrome or `False` if `txt`
#   is not a palindrome.
#
# ## How will we test our function along the way?
# We will use the following test cases to guide us:
#
# The following should all return `True`:
# ```
# isPalindrome('wow')
# isPalindrome('12a3a21')
# isPalindrome('Anna')
# isPalindrome('race car')
# isPalindrome('Was it a cat I saw?')
# ```
#
# The following should all return `False`:
# ```
# isPalindrome('wowza')
# isPalindrome('123a21')
# isPalindrome('<3 mom <3')
# ```

# %%
def isPalindrome(txt):
    """Checks whether an input string is a palindrome.
    
    Arguments:
        txt (string): the phrase we want to test
    """
    # Make everything lowercase. (e.g. Anna -> anna)
    txt = txt.lower()
    print('Lowercased: ' + txt)
    
    # Replace all spaces with an empty string
    txt = txt.replace(' ', '')
    print('No spaces: ' + txt)
    
    # Replace all spaces with an empty string
    txt = txt.replace('?', '')
    print('No question marks: ' + txt)
    
    # How is the phrase spelled forwards?
    forwards = txt
    print('Forwards:  ' + forwards)
    
    # How is it spelled backwards?
    backwards = txt[::-1]
    print('Backwards: ' + backwards)
    
    # If the forwards spelling is the same as the backwards spelling,
    if forwards == backwards:
        # then its a palindrome! (and print True)
        print('It\'s a palindrome, True!')
    else:
        print('It\'s NOT a palindrome, False!')
        # Else, it's not. (and print False)
    
    print('----')

# %%
print('--- all of these should be true ---')
isPalindrome('wow')
isPalindrome('12a3a21')
isPalindrome('Anna') # this is a problem
isPalindrome('race car')
isPalindrome('Was it a cat I saw?')

print('\n--- all of these should be false ---')
isPalindrome('wowza')
isPalindrome('123a21')
isPalindrome('<3 mom <3')
# Out:
# --- all of these should be true ---
# Lowercased: wow
# No spaces: wow
# No question marks: wow
# Forwards:  wow
# Backwards: wow
# It's a palindrome, True!
# ----
# Lowercased: 12a3a21
# No spaces: 12a3a21
# No question marks: 12a3a21
# Forwards:  12a3a21
# Backwards: 12a3a21
# It's a palindrome, True!
# ----
# Lowercased: anna
# No spaces: anna
# No question marks: anna
# Forwards:  anna
# Backwards: anna
# It's a palindrome, True!
# ----
# Lowercased: race car
# No spaces: racecar
# No question marks: racecar
# Forwards:  racecar
# Backwards: racecar
# It's a palindrome, True!
# ----
# Lowercased: was it a cat i saw?
# No spaces: wasitacatisaw?
# No question marks: wasitacatisaw
# Forwards:  wasitacatisaw
# Backwards: wasitacatisaw
# It's a palindrome, True!
# ----
#
# --- all of these should be false ---
# Lowercased: wowza
# No spaces: wowza
# No question marks: wowza
# Forwards:  wowza
# Backwards: azwow
# It's NOT a palindrome, False!
# ----
# Lowercased: 123a21
# No spaces: 123a21
# No question marks: 123a21
# Forwards:  123a21
# Backwards: 12a321
# It's NOT a palindrome, False!
# ----
# Lowercased: <3 mom <3
# No spaces: <3mom<3
# No question marks: <3mom<3
# Forwards:  <3mom<3
# Backwards: 3<mom3<
# It's NOT a palindrome, False!
# ----
